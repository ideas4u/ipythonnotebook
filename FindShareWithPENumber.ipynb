# %%
import tushare as ts

# %%
 share_list = ts.get_stock_basics()

# %%
share_list.head()
# Out:
#          name industry area      pe  outstanding      totals   totalAssets  \
# code
# 000001   平安银行       银行   深圳    7.31   1180405.50  1430867.63  2.570508e+08
# 000002  万  科Ａ     全国地产   深圳   16.21    971771.56  1104805.75  5.369377e+07
# 000004   国农科技     生物制药   深圳  905.17      8387.54     8397.66  3.486601e+04
# 000005   世纪星源     区域地产   深圳    0.00     91374.29    91433.35  1.341597e+05
# 000006   深振业Ａ     区域地产   深圳   24.66    134148.73   134999.50  1.177060e+06
#
#         liquidAssets  fixedAssets    reserved  reservedPerShare    esp   bvps  \
# code
# 000001          0.00    369000.00  5932600.00              4.15  0.840  10.54
# 000002   48999152.00    376758.91   832910.63              0.75  0.439   7.90
# 000004      27242.49      3879.12       66.45              0.01  0.014   0.97
# 000005      22245.80      2536.10    26976.98              0.30 -0.025   0.71
# 000006     953584.13       368.26    48432.15              0.36  0.191   3.14
#
#            pb  timeToMarket
# ...

# %%
share_list.columns
# Out:
# Index(['name', 'industry', 'area', 'pe', 'outstanding', 'totals',
#        'totalAssets', 'liquidAssets', 'fixedAssets', 'reserved',
#        'reservedPerShare', 'esp', 'bvps', 'pb', 'timeToMarket'],
#       dtype='object')

# %%
share_list_pe_lessthan_7 = share_list[share_list['pe'] < 7]
share_list_pe_lessthan_7_greatthan_0 = share_list_pe_lessthan_7[share_list_pe_lessthan_7['pe']>0]
share_list_pe_lessthan_7_greatthan_0.sort(columns='pe').to_excel('f:\\test\\PE小于7的股票.xlsx',sheet_name='Sheet1')

# %%
share_list_pe_lessthan_13 = share_list[share_list['pe'] < 13]
share_list_pe_lessthan_13_greatthan_7 = share_list_pe_lessthan_13[share_list_pe_lessthan_13['pe']>7]
share_list_pe_lessthan_13_greatthan_7.sort(columns='pe').to_excel('f:\\test\\PE小于13大于7的股票.xlsx',sheet_name='Sheet1')

# %%
share_list_pe_lessthan_7_greatthan_0.sort(columns='pe')
# Out:
#         name industry area    pe  outstanding       totals   totalAssets  \
# code
# 600177   雅戈尔       服饰   浙江  4.99    222661.17    222661.17  4.597800e+06
# 601166  兴业银行       银行   福建  5.05   1617961.63   1905233.63  5.125903e+08
# 600185  格力地产     区域地产   广东  5.07     57761.37     57761.37  1.992482e+06
# 601288  农业银行       银行   北京  5.25  29405530.00  32479412.00  1.745955e+09
# 601939  建设银行       银行   北京  5.61    959365.75  25001098.00  1.821919e+09
# 601169  北京银行       银行   北京  5.61   1267223.00   1267223.00  1.624228e+08
# 600000  浦发银行       银行   上海  5.81   1492277.75   1865347.13  4.603740e+08
