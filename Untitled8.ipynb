# %%
import os

# %%
os.chdir('c:\\users\\xiewy')
os.listdir()
# Out:
# ['.android',
#  '.bash_history',
#  '.config',
#  '.eclipse',
#  '.enstaller4rc',
#  '.git',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jmc',
#  '.matplotlib',
#  '.oanda',
#  '.octave_hist',
#  '.ssh',
#  '.thinkbuzan',
#  '.VirtualBox',
#  '1205',
#  '201408_babs_open_data',
#  'AdobeAIRInstaller.exe',
#  'AppData',
#  'appliance50-2014-vbox (1).ova.sgdownload',
#  'appliance50-2014-vbox.ova.sgdownload',
#  'Application Data',
#  'ascii_log_file',
#  'au.R',
#  'awesome-python',
#  'baidu',
#  'baidu1126.xml',
#  'Canopy',
#  'cart.py',
#  'cart.py~',
#  'Central Idea.imx',
#  'choices.csv',
#  'choices.xlsx',
#  'class_of_bird.py',
#  'Contacts',
#  'Cookies',
#  'countnum.R',
#  'csv_mindex.csv',
#  'Curriculum Planner.imx',
#  'dailyreport.py',
#  'data.csv',
#  'data.txt',
#  'Desktop',
#  'dictdata.csv',
#  'dirbot',
#  'dkeyinst.exe',
#  'Documents',
#  'Downloads',
#  'echo.txt',
#  'echo1.txt',
#  'euranlys.py',
#  'EurekaLog',
# ...
